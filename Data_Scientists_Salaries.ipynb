# %% [markdown]
# <a href="https://colab.research.google.com/github/bill-close/Data-Scientist-Salaries/blob/main/Data_Scientists_Salaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url ="https://raw.githubusercontent.com/bill-close/Data-Scientist-Salaries/main/ds_salaries.csv"

# %%
dataset = pd.read_csv(url)

# %%
dataset.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
data = dataset.loc[dataset['salary_currency'] == 'AUD']
data
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 503         503       2022               MI              FT
# 505         505       2022               EN              FT
#
#                      job_title  salary salary_currency  salary_in_usd  \
# 503  Machine Learning Engineer  121000             AUD          87425
# 505             Data Scientist  120000             AUD          86703
#
#     employee_residence  remote_ratio company_location company_size
# 503                 AU           100               AU            L
# 505                 AU            50               AU            M

# %% [markdown]
# Thank you kaggle
#
# https://www.kaggle.com/datasets/ruchi798/data-science-job-salaries
